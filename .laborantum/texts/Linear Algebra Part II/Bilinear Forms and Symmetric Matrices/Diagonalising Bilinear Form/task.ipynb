# %%
import numpy as np
import json_tricks

# %%
### YOUR CODE HERE ###

# %%
answer = {
    'task1': {
        'canonical': {
            'det(A - lI)': [
                1, -6, 8
            ],
            'Lambda': np.array(
                [[4, 0], [0, 2]]
            ),
            'Q': np.array(
                [[0.7071067811865475, 0.7071067811865475],
                 [0.7071067811865475, -0.7071067811865475]]
            ),
            'C': np.array([
                [[0.7071067811865475, 0.7071067811865475],
                 [0.7071067811865475, -0.7071067811865475]]
            ]),
            'd': np.array(
                [4, 2]
            ),
            'definiteness':
              "+"
        },
        'LDL': {
            'D': np.array([
                [[3.0, 0.0], [0.0, 2.6666666666666665]]
            ]),
            'L': np.array(
                [[1.0, 0.0], [0.3333333333333333, 1.0]]
            ),
            'C': np.array([
                [[1.0, 0.3333333333333333], [0.0, 1.0]]
            ]),
            'd': np.array([
                [3.0, 2.6666666666666665]
            ]),
            'definitiness': str(
                "+"
            )
        },
        'dets':{
            '1x1': [
                1.5
            ],
            '2x2': [
                9, -1
            ],
            'definiteness': str(
                "+"
            )
        }
    },
    'task2': {
        'canonical': {
            'det(A - lI)': [
                1, 15, 58
            ],
            'Lambda': np.array(
                [[-10, 0], [0, -5]]
            ),
            'Q': np.array(
                [[0.4472135954999579, 0.8944271909999159],
                 [0.8944271909999159, -0.4472135954999579]]
            ),
            'C': np.array([
                [[0.4472135954999579, 0.8944271909999159],
                 [0.8944271909999159, -0.4472135954999579]]
            ]),
            'd': np.array(
                [-10, -5]
            ),
            'definiteness':
              "-"
        },
        'LDL': {
            'D': np.array([
                [[-6.0, 0.0], [0.0, -8.333333333333334]]
            ]),
            'L': np.array(
                [[1.0, 0.0], [0.3333333333333333, 1.0]]
            ),
            'C': np.array([
                [[1.0, 0.3333333333333333], [0.0, 1.0]]
            ]),
            'd': np.array([
                [-6.0, -8.333333333333334]
            ]),
            'definitiness': str(
                "-"
            )
        },
        'dets':{
            '1x1': [
                -6
            ],
            '2x2': [
                54, 4
            ],
            'definiteness': str(
                "-"
            )
        }
    },
    'task3': {
        'canonical': {
            'det(A - lI)': [
                -1, 6, -9, 4
            ],
            'Lambda': np.array(
                [[4, 0, 0], [0, 1, 0], [0, 0, 1]]
            ),
            'Q': np.array(
                [[0.5773502691896258, 0.8164965809277261, 0.0],
                 [0.5773502691896258, -0.4082482904638631, 0.7071067811865475],
                 [0.5773502691896258, -0.4082482904638631, -0.7071067811865475]]
            ),
            'C': np.array([
                [[0.5773502691896258, 0.5773502691896258, 0.5773502691896258],
                 [0.8164965809277261, -0.4082482904638631, -0.4082482904638631],
                 [0.0, 0.7071067811865475, -0.7071067811865475]]
            ]),
            'd': np.array(
                [4, 1, 1]
            ),
            'definiteness':
              "+"
        },
        'LDL': {
            'D': np.array([
               [[2.0, 0.0, 0.0],
                [0.0, 1.5, 0.0], 
                [0.0, 0.0, 1.3333333333333333]]
            ]),
            'L': np.array(
                [[1.0, 0.0, 0.0], [0.5, 1.0, 0.0], [0.5, 0.3333333333333333, 1.0]]
            ),
            'C': np.array([
                [[1.0, 0.5, 0.5], [0.0, 1.0, 0.3333333333333333], [0.0, 0.0, 1.0]]
            ]),
            'd': np.array([
                [2.0, 1.5, 1.3333333333333333]
            ]),
            'definitiness': str(
                "+"
            )
        },
        'dets':{
            '1x1': [
                2
            ],
            '2x2': [
                4, -1
            ],
            '3x3': [
                8, 1, 1, -2, -2, -2
            ],
            'definiteness': str(
                "+"
            )
        }
    },
}

json_tricks.dump(answer, '.answer.json')

json_tricks.dump(answer, '.answer.json')
